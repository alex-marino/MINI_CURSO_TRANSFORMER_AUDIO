# %% [markdown]
# # Capítulo 4 – Modelos de Transformers para Áudio
#
# > Este notebook mostra como extrair embeddings com Wav2Vec2 usando `transformers`.

# %%
# (Opcional) Instalar dependências em um ambiente local
# !pip install torch torchaudio transformers librosa

# %% [markdown]
# ## Extração de embeddings com Wav2Vec2

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2Model
import torch, librosa, numpy as np

processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base")

y, sr = librosa.load("voz_exemplo.wav", sr=16000)  # ajuste o caminho conforme necessário
inputs = processor(y, sampling_rate=sr, return_tensors="pt", padding=True)

with torch.no_grad():
    outputs = model(**inputs)
embeddings = outputs.last_hidden_state.mean(dim=1).numpy()
embeddings.shape
